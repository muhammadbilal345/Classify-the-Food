# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Muhammad Bilal</b>
#
# Student

# %% [markdown]
# <i>I am interested in Data Science because it solves our real world problems by extracting insights from the data that are beneficial for our business.</i>

# %% [markdown]
# ### The code which I written below is the sum function to add the two number and returns the result.

# %%
def sum(a, b):
    return a+b
sum(7, 8)
# Out:
# 15

# %% [markdown]
# <b>Numbered List</b>
# <ol>
#     <li>Data Science</li>
#     <li>Machine Learning</li>
#     <li>Deep Learning</li>
# <ol>

# %% [markdown]
# <b>Bulleted List</b>
# <ul>
#     <li>Data Science</li>
#     <li>Machine Learning</li>
#     <li>Deep Learning</li>
# <ul>

# %% [markdown]
# <b>Strikethrough</b>
# <br>
# <s>This text is strikethrough</s>
